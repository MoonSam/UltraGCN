# %%
import pstats
p = pstats.Stats("profile.stats")
p.sort_stats("cumulative")

# %%
p.print_stats()
# Out:
# Thu Sep  8 06:02:34 2022    profile.stats
#
#          159939582 function calls (159437194 primitive calls) in 2040.619 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    1362/1    0.023    0.000 2040.655 2040.655 {built-in method builtins.exec}
#         1    2.001    2.001 2040.652 2040.652 main.py:1(<module>)
#         1    3.774    3.774 1459.823 1459.823 main.py:384(train)
#    314033  582.238    0.002  582.255    0.002 {method 'to' of 'torch._C._TensorBase' objects}
# 209406/35031    0.836    0.000  568.388    0.016 /home/moon/anaconda3/envs/ultra/lib/python3.7/site-packages/torch/nn/modules/module.py:522(__call__)
#     34875    2.111    0.000  567.908    0.016 main.py:358(forward)
#         1    0.001    0.001  522.636  522.636 /home/moon/anaconda3/envs/ultra/lib/python3.7/site-packages/torch/nn/modules/module.py:349(to)
# ...

# %%
p.print_callers()
# Out:
#    Ordered by: cumulative time
#
# Function                                                                                                                                             was called by...
#                                                                                                                                                          ncalls  tottime  cumtime
# {built-in method builtins.exec}                                                                                                                      <-      51    0.018    0.018  /home/moon/anaconda3/envs/ultra/lib/python3.7/collections/__init__.py:316(namedtuple)
#                                                                                                                                                             316    0.000    0.002  /home/moon/anaconda3/envs/ultra/lib/python3.7/site-packages/numpy/core/overrides.py:166(decorator)
# ...

# %%
p.print_callees()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
